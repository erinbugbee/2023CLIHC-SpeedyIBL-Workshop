# %% [markdown]
# ## References
# <b id="f1">[1]</b> Cleotilde Gonzalez, Javier F. Lerch and Christian Lebiere (2003), [Instance-based learning in dynamic decision making](https://www.sciencedirect.com/science/article/abs/pii/S0364021303000314), Cognitive Science, 27, 591-635. DOI: 10.1016/S0364-0213(03)00031-4.
#
# <b id="f2">[2]</b> Thuy Ngoc Nguyen, Duy Nhat Phan, Cleotilde Gonzalez (2022), [SpeedyIBL: A Comprehensive, Precise, and Fast Implementation of
# Instance-Based Learning Theory](https://link.springer.com/article/10.3758/s13428-022-01848-x)

# %% [markdown]
# ## Installing SpeedyIBL
# Speedyibl library is a Python module, which is stored at PyPI (pypi.org), a repository of software for the Python programming language, see https://pypi.org/project/speedyibl/. One can install SpeedyIBL by using the following command line:

# %%
# %pip install -U speedyibl
# Out:
# Collecting speedyibl
#   Using cached speedyibl-0.2.3-py3-none-any.whl (13 kB)
# Requirement already satisfied: tabulate in /opt/miniconda3/envs/env_nhb/lib/python3.8/site-packages (from speedyibl) (0.8.9)
# Requirement already satisfied: wheel in /opt/miniconda3/envs/env_nhb/lib/python3.8/site-packages (from speedyibl) (0.37.0)
# Requirement already satisfied: setuptools>=42 in /opt/miniconda3/envs/env_nhb/lib/python3.8/site-packages (from speedyibl) (58.0.4)
# Requirement already satisfied: numpy in /opt/miniconda3/envs/env_nhb/lib/python3.8/site-packages (from speedyibl) (1.19.3)
# Installing collected packages: speedyibl
# Successfully installed speedyibl-0.2.3
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Importing and describing the class Agent of SpeedyIBL
#
# After installing the library, we need to import the class Agent of SpeedyIBL by typing:

# %%
from speedyibl import Agent

# %% [markdown]
# To view a list of attributes / inputs of the class Agent:

# %%
help(Agent.__init__)
# Out:
# Help on function __init__ in module speedyibl:
#
# __init__(self, default_utility=0.1, noise=0.25, decay=0.5, mismatchPenalty=None, outcome=True, lendeque=250000)
#     Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# To display a list of functions / methods of the class Agent:

# %%
vars(Agent)
# dir(Agent)
# Out:
# mappingproxy({'__module__': 'speedyibl',
#               'mkid': 0,
#               '__init__': <function speedyibl.Agent.__init__(self, default_utility=0.1, noise=0.25, decay=0.5, mismatchPenalty=None, outcome=True, lendeque=250000)>,
#               'respond': <function speedyibl.Agent.respond(self, reward)>,
#               'populate_at': <function speedyibl.Agent.populate_at(self, option, t, reward=None)>,
#               'make_noise': <function speedyibl.Agent.make_noise(self)>,
#               'choose': <function speedyibl.Agent.choose(self, options, base=None)>,
#               'reset': <function speedyibl.Agent.reset(self)>,
#               'instances': <function speedyibl.Agent.instances(self)>,
#               'prepopulate': <function speedyibl.Agent.prepopulate(self, option, reward=None)>,
#               'similarity': <function speedyibl.Agent.similarity(self, attributes, function)>,
#               'get_similarity': <function speedyibl.Agent.get_similarity(self, option, option2=None)>,
#               'equal_delay_feedback': <function speedyibl.Agent.equal_delay_feedback(self, reward, episode_history)>,
#               'CompActivation': <function speedyibl.Agent.CompActivation(self, t, o, base=None)>,
#               'CompProbability': <function speedyibl.Agent.CompProbability(self, t, o, base=None)>,
#               'CompBlended': <function speedyibl.Agent.CompBlended(self, t, options, base=None)>,
#               '__dict__': <attribute '__dict__' of 'Agent' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Agent' objects>,
#               '__doc__': None})
