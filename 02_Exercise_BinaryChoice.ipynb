# %% [markdown]
# <a href="https://colab.research.google.com/github/erinbugbee/2023CLIHC-SpeedyIBL-Workshop/blob/main/02_Exercise_BinaryChoice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
# </a>
#
# # Using SpeedyIBL for Binary Choice Task
#
# In this task, the agent must choose one of two options: Option A or Option B. A numerical outcome drawn from a distribution after the selection is the **immediate** feedback of the task.
# + One option is safe, and it yields a fixed medium outcome (3)
# + The other option is risky, and it returns a high outcome (4) with probability 0.8 and a low outcome (0) with the complementary probability 0.2
#
# <!-- <div style="text-align:center"> -->
# <a target="_parent">
#     <img src="https://raw.githubusercontent.com/ngocntkt/visualization-map/master/speedyibl_binary_choice.png" width="80%" style="background-color:white";/>
# </a>

# %% [markdown]
# ### Create an Environment for the Binary Choice Task

# %%
import random

class BinaryChoice:
    def __init__(self):
        self.options = ['A', 'B']
    
    def reward(self, choice):
        # A is the safe option while B is the risky option
        if choice == 'A': 
            r = 3
        elif random.random() <= 0.8:
            r = 4
        else:
            r = 0
        return r

# %%
env = BinaryChoice()
env.options
# Out:
# ['A', 'B']

# %% [markdown]
# ### Build an IBL Agent for the Binary Choice Task

# %%
# !pip install -U speedyibl

# %%
from speedyibl import Agent

# %% [markdown]
# We create an IBL agent with `default_utility` of 4.4.

# %%
agent = Agent(default_utility=4.4)

# %% [markdown]
# #### Exercise: Create an IBL agent with
# + `default_utility` of 3, `noise` of 0.25 and `decay` of 0.5
# + `default_utility` of 4.4, `noise` of 0.25 and `decay` of 0.8

# %% [markdown]
# ### IBL Agent Interacts with the Binary Choice Task

# %% [markdown]
# We are ready to make the agent choose one of the two options:

# %%
choice = agent.choose(env.options)

# %% [markdown]
# After choosing one option and observing the reward, we use the function `respond` to store the instance in the memory as follows:

# %%
print(f"The agent selected option: {choice}")
r = env.reward(choice)
print(f"The agent receives reward of: {r}")
agent.respond(r)
# Out:
# The agent selected option: A
# The agent receives reward of: 3

# %%
##Agent chooses an option again, observes the reward and stores it in memory ....
choice = agent.choose(env.options)
print(f"The agent selected option: {choice}")
r = env.reward(choice)
print(f"The agent receives reward of: {r}")
agent.respond(r)
# Out:
# The agent selected option: B
# The agent receives reward of: 0

# %% [markdown]
# ### Display how instances are stored in the IBL Agent's Memory

# %%
agent.instances()
# Out:
# option      outcome  occurences
# --------  ---------  ------------
# A               3    [1]
# A               4.4  [0]
# B               0    [2]
# B               4.4  [0]

# %% [markdown]
# ### Display the IBL Agent's Decision Mechanisms

# %% [markdown]
# ##### Calculating the activation of each instance

# %%
activation = agent.CompActivation(agent.t+1, 'A')
print(activation)
for i in range(len(activation[0])):
    print(f"The activation of the instance: (A, {activation[1][i]}): {activation[0][i]}")
# Out:
# (array([-0.99694213, -0.08365432]), array([3. , 4.4]))
# The activation of the instance: (A, 3.0): -0.9969421283189399
# The activation of the instance: (A, 4.4): -0.08365431826290648

# %%
activation = agent.CompActivation(agent.t+1, 'B')
print(activation)
for i in range(len(activation[0])):
    print(f"The activation of the instance: (B, {activation[1][i]}): {activation[0][i]}")
# Out:
# (array([ 0.04606415, -0.09921906]), array([0. , 4.4]))
# The activation of the instance: (B, 0.0): 0.04606414699130387
# The activation of the instance: (B, 4.4): -0.09921906057348134

# %% [markdown]
# ##### Calculating the probability of retrieving each instance

# %%
prob = agent.CompProbability(agent.t+1, 'A')
print(prob)
for i in range(len(prob[0])):
    print(f"The probability of retrieval of the instance: (A, {prob[1][i]}): {prob[0][i]}")
# Out:
# (array([0.05791146, 0.94208854]), array([3. , 4.4]))
# The probability of retrieval of the instance: (A, 3.0): 0.057911459870401596
# The probability of retrieval of the instance: (A, 4.4): 0.9420885401295984

# %%
prob = agent.CompProbability(agent.t+1, 'B')
print(prob)
for i in range(len(prob[0])):
    print(f"The probability of retrieval of the instance: (B, {prob[1][i]}): {prob[0][i]}")
# Out:
# (array([0.44175385, 0.55824615]), array([0. , 4.4]))
# The probability of retrieval of the instance: (B, 0.0): 0.44175385287237
# The probability of retrieval of the instance: (B, 4.4): 0.5582461471276299

# %% [markdown]
# ##### Calculating the blended value for each option

# %%
blended = agent.CompBlended(agent.t+1, env.options)
print(blended)
print(f"Blended value of Option A is: {blended[0][0]}")
print(f"Blended value of Option B is: {blended[1][0]}")
# Out:
# [(3.7166148632995126, 0), (2.410049392384742, 1)]
# Blended value of Option A is: 3.7166148632995126
# Blended value of Option B is: 2.410049392384742

# %% [markdown]
# ### Let the IBL Agent play the Binary Choice task 100 times

# %% [markdown]
# Let the agent play 100 rounds (trials) for the binary choice task.
#
# Each round includes choosing one option, observing the reward, and storing the instance.
#
# We need to count how often the agent selected the option with the highest expected reward (`PMAX`).

# %%
rounds = 100 # number of rounds (trials)
pmax = []
for i in range(rounds):     
    choice = agent.choose(env.options) # choose one option from the list of options
    r = env.reward(choice) # observe the reward 
    agent.respond(r) # store the instance
    pmax.append(choice == 'B')

# %%
print(f"P(Max): {sum(pmax)/rounds}")
# Out:
# P(Max): 0.61

# %% [markdown]
# ### Let have 500 runs (500 simulated subjects) playing 100-round Binary Choice task.
# + Each agent plays 100 rounds of the binary choice task.
# + On average, how often the agents selected the option with the highest expected reward (`PMAX`).

# %%
runs = 500
rounds = 100 # number of rounds (trials)
pmax_per_run = []
for j in range(runs):
    pmax = []
    agent.reset() #clear the memory for a new run
    for i in range(rounds):     
        choice = agent.choose(env.options) #choose one option from the list of options
        r = env.reward(choice) # obsere the reward 
        agent.respond(r) # store the instance
        pmax.append(choice == 'B') 
    pmax_per_run.append(pmax)

# %%
import matplotlib.pyplot as plt
import numpy as np 
plt.plot(range(rounds), np.mean(pmax_per_run,axis=0), color='darkgreen',
          markersize=2, linestyle='--', label='speedyIBL')
plt.xlabel('Round')
plt.ylabel('PMAX')
plt.title('Performance')
plt.ylim(0,1)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Exercise 1
# Simulate the effect of the IBL model inputs in the Binary Choice Task with the following parameters:
# + `default_utility` of 3, `noise` of 0.25, and `decay` of 0.5
# + `default_utility` of 4.4, `noise` of 0.5, and `decay` of 0.8

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# Build an IBL Agent using `default_utility` of 4.4, `decay` of 0.5 and `noise` of 0.25 for the new binary choice task. The options are Option A or Option B.
# + One option is safe, and it yields a fixed medium outcome (3)
# + The other option is risky, and it returns a high outcome (32) with probability 0.1 and a low outcome (0) with the complementary probability 0.9
